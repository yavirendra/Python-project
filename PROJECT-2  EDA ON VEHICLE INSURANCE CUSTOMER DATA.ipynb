# %% [markdown]
# # PROJECT-2
# # EDA ON VEHICLE INSURANCE CUSTOMER DATA

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# loading the data files
customerDetails=pd.read_csv('customer_details.csv')
customerpolDetails=pd.read_csv('customer_policy_details.csv')

# %% [markdown]
# # Column Name for customer details table:
# customer_id,
# Gender,
# age,
# driving licence present,
# region code,
# previously insured,
# vehicle age
# and vehicle damage, in respective order.

# %%
customerDetails.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
customerDetails.rename(columns={'0':'customer_id','1':'Gender','2':'age','3':'driving licence present','4':'region code','5':'previously insured','6':'vehicle age','7':'vehicle damage'})
# Out:
#         customer_id  Gender   age  driving licence present  region code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously insured vehicle age vehical damage
# 0                      0.0   > 2 Years            Yes
# 1                      0.0    1-2 Year             No
# 2                      0.0   > 2 Years            Yes
# 3                      1.0    < 1 Year             No
# 4                      1.0    < 1 Year             No
# ...                    ...         ...            ...
# 381104                 1.0    1-2 Year             No
# 381105                 1.0    < 1 Year             No
# 381106                 1.0    < 1 Year             No
# 381107                 0.0   > 2 Years            Yes
# 381108                 0.0    1-2 Year             No
#
# [380317 rows x 8 columns]

# %%
customerDetails=customerDetails.rename(columns={'0':'customer_id','1':'Gender','2':'age','3':'driving licence present','4':'region code','5':'previously insured','6':'vehicle age','7':'vehicle damage'})

# %%
customerDetails.columns
# Out:
# Index(['customer_id', 'Gender', 'age', 'driving licence present',
#        'region code', 'previously insured', 'vehicle age', 'vehical damage'],
#       dtype='object')

# %% [markdown]
# # Column Name for customer_policy table:
# customer_id,
# annual premium (in Rs),
# sales channel code,
# vintage and response.

# %%
customerpolDetails.columns
# Out:
# Index(['0', '1', '2', '3', '4'], dtype='object')

# %%
customerpolDetails.rename(columns={'0':'customer_id','1':'annual premium (in Rs)','2':'sales channel code','3':'vintage','4':'response'})
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            0.0
# ...          ...
# 381104       0.0
# 381105       0.0
# 381106       0.0
# 381107       0.0
# 381108       0.0
#
# [381109 rows x 5 columns]

# %%
customerpolDetails=customerpolDetails.rename(columns={'0':'customer_id','1':'annual premium (in Rs)','2':'sales channel code','3':'vintage','4':'response'})

# %%
customerpolDetails.columns
# Out:
# Index(['customer_id', 'annual premium (in Rs)', 'sales channel code',
#        'vintage', 'response'],
#       dtype='object')

# %% [markdown]
# # Q2. Checking and Cleaning Data Quality:

# %%
# Generate a summary of count of all the null values column wise.
customerDetails.isnull().sum()
# Out:
# customer_id                386
# Gender                     368
# age                        368
# driving licence present    393
# region code                392
# previously insured         381
# vehicle age                381
# vehical damage             407
# dtype: int64

# %%
customerpolDetails.isnull().sum()
# Out:
# customer_id               387
# annual premium (in Rs)    346
# sales channel code        400
# vintage                   388
# response                  361
# dtype: int64

# %%
customerDetails['customer_id'].isna().sum()
# Out:
# 386

# %%
customerDetails['customer_id'].count()
# Out:
# 380723

# %%
customerpolDetails['customer_id'].isna().sum()
# Out:
# 387

# %%
customerpolDetails['customer_id'].count()
# Out:
# 380722

# %%
## Replace all null values for numeric columns by mean.
## Drop Null values for customer_id

customerpolDetails = customerpolDetails.dropna(subset=['customer_id'])

# %%
customerpolDetails['customer_id'].mean()
# Out:
# 190547.49166320832

# %%
customerpolDetails['annual premium (in Rs)'].fillna((customerpolDetails['annual premium (in Rs)'].mean()),inplace=True)
customerpolDetails['annual premium (in Rs)'].mean()
# Out:
# 30563.999773909116

# %%
customerpolDetails['sales channel code'].fillna((customerpolDetails['sales channel code'].mean()),inplace=True)
customerpolDetails['sales channel code'].mean()
# Out:
# 112.03668733336488

# %%
customerpolDetails['vintage'].fillna((customerpolDetails['vintage'].mean()),inplace=True)
customerpolDetails['vintage'].mean()
# Out:
# 154.34719220474634

# %%
customerpolDetails['response'].fillna((customerpolDetails['response'].mean()),inplace=True)
customerpolDetails['response'].mean()
# Out:
# 0.12252570584260743

# %%
customerpolDetails.isnull().sum()
# Out:
# customer_id               0
# annual premium (in Rs)    0
# sales channel code        0
# vintage                   0
# response                  0
# dtype: int64

# %%
customerDetails = customerDetails.dropna(subset=['customer_id'])
customerDetails = customerDetails.dropna(subset=['vehical damage'])
customerDetails = customerDetails.dropna(subset=['vehicle age'])
customerDetails = customerDetails.dropna(subset=['previously insured'])
customerDetails = customerDetails.dropna(subset=['region code'])
customerDetails = customerDetails.dropna(subset=['driving licence present'])
customerDetails = customerDetails.dropna(subset=['Gender'])
customerDetails = customerDetails.dropna(subset=['age'])

# %%
customerDetails['customer_id'].fillna((customerDetails['customer_id'].mode()), inplace=True)
customerDetails['Gender'].fillna((customerDetails['Gender'].mode().iloc[0]), inplace=True)
customerDetails['age'].fillna((customerDetails['age'].mode().iloc[0]), inplace=True)
customerDetails['region code'].fillna((customerDetails['region code'].mode().iloc[0]),inplace=True)
customerDetails['previously insured'].fillna((customerDetails['previously insured'].mode().iloc[0]),inplace=True)
customerDetails['vehicle age'].fillna((customerDetails['vehicle age'].mode().iloc[0]),inplace=True)
customerDetails['driving licence present'].fillna((customerDetails['driving licence present'].mode().iloc[0]),inplace=True)
customerDetails['vehical damage'].fillna((customerDetails['vehical damage'].mode().iloc[0]),inplace=True)

# %%
customerDetails.isnull().sum()
# Out:
# customer_id                0
# Gender                     0
# age                        0
# driving licence present    0
# region code                0
# previously insured         0
# vehicle age                0
# vehical damage             0
# dtype: int64

# %% [markdown]
# # Generate a summary of count of all the outliers column wise

# %%
customerDetails.describe()
# Out:
#          customer_id            age  driving licence present    region code  \
# count  380317.000000  380317.000000            380317.000000  380317.000000
# mean   190553.574968      38.808870                 0.997868      26.391771
# std    110014.036357      15.511782                 0.046129      13.223589
# min         1.000000      20.000000                 0.000000       0.000000
# 25%     95283.000000      25.000000                 1.000000      15.000000
# 50%    190545.000000      36.000000                 1.000000      28.000000
# 75%    285826.000000      49.000000                 1.000000      35.000000
# max    381109.000000      85.000000                 1.000000      52.000000
#
#        previously insured
# count       380317.000000
# mean             0.457794
# std              0.498216
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000

# %%
customerpolDetails.describe()
# Out:
#          customer_id  annual premium (in Rs)  sales channel code  \
# count  380722.000000           380722.000000       380722.000000
# mean   190547.491663            30563.999774          112.036687
# std    110013.824148            17190.147550           54.177046
# min         1.000000             2630.000000            1.000000
# 25%     95276.250000            24416.000000           29.000000
# 50%    190536.500000            31656.000000          131.000000
# 75%    285818.750000            39391.750000          152.000000
# max    381109.000000           540165.000000          163.000000
#
#              vintage       response
# count  380722.000000  380722.000000
# mean      154.347192       0.122526
# std        83.628096       0.327737
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %% [markdown]
# # Replace all outlier values for numeric columns by mean.

# %%
Q1=customerpolDetails.quantile(0.25)
Q3=customerpolDetails.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# customer_id               190542.50
# annual premium (in Rs)     14975.75
# sales channel code           123.00
# vintage                      145.00
# response                       0.00
# dtype: float64

# %%
customerDetails = customerDetails.rename(columns={'Gender':'Gender','driving licence present':'driving_licence_present','previously insured':'previously insured','vehicle age':'vehicle age','vehical damage':'vehical damage'})

# %%
Gender = {'Male': 0, 'Female': 1}
driving_licence_present = {0: 0, 1: 1}
previously_insured = {0: 1, 1: 0}
vehicle_age = {'> 2 Years': 2, '1-2 Year': 1, '< 1 Year': 0}
vehicle_damage = {'Yes': 1, 'No': 0}
customerDetails['Gender'] = customerDetails['Gender'].map(Gender)
customerDetails['driving_licence_present'] = customerDetails['driving_licence_present'].map(driving_licence_present)
customerDetails['previously insured'] = customerDetails['previously insured'].map(previously insured)
customerDetails['vehicle_age'] = customerDetails['vehicle_age'].map(vehicle_age)
customerDetails['vehical_damage'] = customerDetails['vehical_damage'].map(vehical_damage)
# Out:
#   Cell In[119], line 8
#     customerDetails['previously insured'] = customerDetails['previously insured'].map(previously insured)
#                                                                                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
customerDetails.head(2)
# Out:
#    customer_id  Gender   age  driving_licence_present  region code  \
# 0          1.0     NaN  44.0                        1         28.0
# 1          2.0     NaN  76.0                        1          3.0
#
#    previously insured vehicle age vehical damage
# 0                 0.0   > 2 Years            Yes
# 1                 0.0    1-2 Year             No

# %%
sns.boxplot(customerpolDetails['annual premium (in Rs)'])
# Out:
# <Axes: >

# %%
percentile25 = customerpolDetails['annual premium (in Rs)'].quantile(0.25)
percentile75 = customerpolDetails['annual premium (in Rs)'].quantile(0.75)
iqr = np.subtract(*np.percentile(1, [75, 25]))
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
customerpolDetails[customerpolDetails['annual premium (in Rs)'] > upper_limit]
customerpolDetails[customerpolDetails['annual premium (in Rs)'] < lower_limit]
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 5               6.0                  2630.0               160.0    176.0
# 6               7.0                 23367.0               152.0    249.0
# 15             16.0                  2630.0               156.0    147.0
# 27             28.0                 19135.0               152.0     57.0
# 30             31.0                  2630.0               160.0    136.0
# ...             ...                     ...                 ...      ...
# 381074     381075.0                 21113.0               152.0    248.0
# 381086     381087.0                  2630.0               152.0    208.0
# 381092     381093.0                  2630.0               124.0    130.0
# 381094     381095.0                  2630.0                26.0     84.0
# 381102     381103.0                  2630.0               152.0    102.0
#
#         response
# 5            0.0
# 6            0.0
# 15           1.0
# 27           0.0
# 30           0.0
# ...          ...
# 381074       0.0
# 381086       0.0
# 381092       0.0
# 381094       0.0
# 381102       0.0
#
# [95178 rows x 5 columns]

# %%
new_df = customerpolDetails[customerpolDetails['annual premium (in Rs)'] < upper_limit]
new_df.shape
# Out:
# (285541, 5)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(customerpolDetails['annual premium (in Rs)'])
plt.subplot(2,2,2)
sns.boxplot(customerpolDetails['annual premium (in Rs)'])
plt.subplot(2,2,3)
sns.distplot(new_df['annual premium (in Rs)'])
plt.subplot(2,2,4)
sns.boxplot(new_df['annual premium (in Rs)'])
plt.show()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\662899790.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(customerpolDetails['annual premium (in Rs)'])
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\662899790.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['annual premium (in Rs)'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 9
#       7 sns.distplot(new_df['annual premium (in Rs)'])
#       8 plt.subplot(2,2,4)
# ----> 9 sns.boxplot(new_df['annual premium (in Rs)'])
#      10 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:486, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     484 if hasattr(data, "shape"):
#     485     if len(data.shape) == 1:
# --> 486         if np.isscalar(data[0]):
#     487             plot_data = [data]
#     488         else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
sns.boxplot(customerpolDetails['vintage'])
# Out:
# <Axes: >

# %%
sns.boxplot(customerpolDetails['sales channel code'])
# Out:
# <Axes: >

# %%
sns.boxplot(customerpolDetails['response'])
# Out:
# <Axes: >

# %%
# Outlier CustomerDetail :
sns.boxplot(customerDetails['age'])
# Out:
# <Axes: >

# %%
sns.boxplot(customerDetails['vehical_damage'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vehical_damage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 sns.boxplot(customerDetails['vehical_damage'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'vehical_damage'

# %%
sns.boxplot(customerDetails['previously insured'])
# Out:
# <Axes: >

# %%
sns.boxplot(customerDetails['region code'])
# Out:
# <Axes: >

# %%
sns.boxplot(customerDetails['vehicle_age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vehicle_age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 sns.boxplot(customerDetails['vehicle_age'])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'vehicle_age'

# %%
# Remove white spaces
customerDetails.apply(lambda x : x.str.strip() if x.dtype == 'object' else x)
# Out:
#         customer_id  Gender   age  driving_licence_present  region code  \
# 0               1.0     NaN  44.0                        1         28.0
# 1               2.0     NaN  76.0                        1          3.0
# 2               3.0     NaN  47.0                        1         28.0
# 3               4.0     NaN  21.0                        1         11.0
# 4               5.0     NaN  29.0                        1         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0     NaN  74.0                        1         26.0
# 381105     381106.0     NaN  30.0                        1         37.0
# 381106     381107.0     NaN  21.0                        1         30.0
# 381107     381108.0     NaN  68.0                        1         14.0
# 381108     381109.0     NaN  46.0                        1         29.0
#
#         previously insured vehicle age vehical damage
# 0                      0.0   > 2 Years            Yes
# 1                      0.0    1-2 Year             No
# 2                      0.0   > 2 Years            Yes
# 3                      1.0    < 1 Year             No
# 4                      1.0    < 1 Year             No
# ...                    ...         ...            ...
# 381104                 1.0    1-2 Year             No
# 381105                 1.0    < 1 Year             No
# 381106                 1.0    < 1 Year             No
# 381107                 0.0   > 2 Years            Yes
# 381108                 0.0    1-2 Year             No
#
# [380317 rows x 8 columns]

# %%
customerpolDetails.apply(lambda x : x.str.strip() if x.dtype == 'object' else x)
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            0.0
# ...          ...
# 381104       0.0
# 381105       0.0
# 381106       0.0
# 381107       0.0
# 381108       0.0
#
# [380722 rows x 5 columns]

# %%
# case correction(lower or upper, any one) 
customerDetails.apply(lambda x : x.str.upper() if x.dtype == 'object' else x)
# Out:
#         customer_id  Gender   age  driving_licence_present  region code  \
# 0               1.0     NaN  44.0                        1         28.0
# 1               2.0     NaN  76.0                        1          3.0
# 2               3.0     NaN  47.0                        1         28.0
# 3               4.0     NaN  21.0                        1         11.0
# 4               5.0     NaN  29.0                        1         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0     NaN  74.0                        1         26.0
# 381105     381106.0     NaN  30.0                        1         37.0
# 381106     381107.0     NaN  21.0                        1         30.0
# 381107     381108.0     NaN  68.0                        1         14.0
# 381108     381109.0     NaN  46.0                        1         29.0
#
#         previously insured vehicle age vehical damage
# 0                      0.0   > 2 YEARS            YES
# 1                      0.0    1-2 YEAR             NO
# 2                      0.0   > 2 YEARS            YES
# 3                      1.0    < 1 YEAR             NO
# 4                      1.0    < 1 YEAR             NO
# ...                    ...         ...            ...
# 381104                 1.0    1-2 YEAR             NO
# 381105                 1.0    < 1 YEAR             NO
# 381106                 1.0    < 1 YEAR             NO
# 381107                 0.0   > 2 YEARS            YES
# 381108                 0.0    1-2 YEAR             NO
#
# [380317 rows x 8 columns]

# %%
#  Convert nominal data (categorical) into dummies 
# for future modeling use if required
dummy_variable = pd.get_dummies(customerDetails['vehical damage'])
dummy_variable.rename(columns={'No':'vehical damage - No','Yes':'vehical damage - Yes'}, inplace = True)

# %%
dummy_variable.head(5)
# Out:
#    vehical damage - No  vehical damage - Yes
# 0                    0                     1
# 1                    1                     0
# 2                    0                     1
# 3                    1                     0
# 4                    1                     0

# %%
customerDetails = pd.concat([customerDetails, dummy_variable], axis = 1)

# %%
customerDetails.head(5)
# Out:
#    customer_id  Gender   age  driving_licence_present  region code  \
# 0          1.0     NaN  44.0                        1         28.0
# 1          2.0     NaN  76.0                        1          3.0
# 2          3.0     NaN  47.0                        1         28.0
# 3          4.0     NaN  21.0                        1         11.0
# 4          5.0     NaN  29.0                        1         41.0
#
#    previously insured vehicle age vehical damage  vehical damage - No  \
# 0                 0.0   > 2 Years            Yes                    0
# 1                 0.0    1-2 Year             No                    1
# 2                 0.0   > 2 Years            Yes                    0
# 3                 1.0    < 1 Year             No                    1
# 4                 1.0    < 1 Year             No                    1
#
#    vehical damage - Yes
# 0                     1
# 1                     0
# 2                     1
# 3                     0
# 4                     0

# %% [markdown]
# # Q3.Create a Master table for future use. Join the customer table and customer_policy table to get a master table using customer_id in both tables.

# %%
customerDetails
# Out:
#         customer_id  Gender   age  driving_licence_present  region code  \
# 0               1.0     NaN  44.0                        1         28.0
# 1               2.0     NaN  76.0                        1          3.0
# 2               3.0     NaN  47.0                        1         28.0
# 3               4.0     NaN  21.0                        1         11.0
# 4               5.0     NaN  29.0                        1         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0     NaN  74.0                        1         26.0
# 381105     381106.0     NaN  30.0                        1         37.0
# 381106     381107.0     NaN  21.0                        1         30.0
# 381107     381108.0     NaN  68.0                        1         14.0
# 381108     381109.0     NaN  46.0                        1         29.0
#
#         previously insured vehicle age vehical damage  vehical damage - No  \
# 0                      0.0   > 2 Years            Yes                    0
# 1                      0.0    1-2 Year             No                    1
# 2                      0.0   > 2 Years            Yes                    0
# 3                      1.0    < 1 Year             No                    1
# 4                      1.0    < 1 Year             No                    1
# ...                    ...         ...            ...                  ...
# 381104                 1.0    1-2 Year             No                    1
# 381105                 1.0    < 1 Year             No                    1
# 381106                 1.0    < 1 Year             No                    1
# 381107                 0.0   > 2 Years            Yes                    0
# 381108                 0.0    1-2 Year             No                    1
#
#         vehical damage - Yes
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          0
# ...                      ...
# 381104                     0
# 381105                     0
# 381106                     0
# 381107                     1
# 381108                     0
#
# [380317 rows x 10 columns]

# %%
customerpolDetails
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            0.0
# ...          ...
# 381104       0.0
# 381105       0.0
# 381106       0.0
# 381107       0.0
# 381108       0.0
#
# [380722 rows x 5 columns]

# %%
master_table = pd.merge(customerDetails,customerpolDetails)

# %%
master_table
# Out:
#         customer_id  Gender   age  driving_licence_present  region code  \
# 0               1.0     NaN  44.0                        1         28.0
# 1               2.0     NaN  76.0                        1          3.0
# 2               3.0     NaN  47.0                        1         28.0
# 3               4.0     NaN  21.0                        1         11.0
# 4               5.0     NaN  29.0                        1         41.0
# ...             ...     ...   ...                      ...          ...
# 379925     381105.0     NaN  74.0                        1         26.0
# 379926     381106.0     NaN  30.0                        1         37.0
# 379927     381107.0     NaN  21.0                        1         30.0
# 379928     381108.0     NaN  68.0                        1         14.0
# 379929     381109.0     NaN  46.0                        1         29.0
#
#         previously insured vehicle age vehical damage  vehical damage - No  \
# 0                      0.0   > 2 Years            Yes                    0
# 1                      0.0    1-2 Year             No                    1
# 2                      0.0   > 2 Years            Yes                    0
# 3                      1.0    < 1 Year             No                    1
# 4                      1.0    < 1 Year             No                    1
# ...                    ...         ...            ...                  ...
# 379925                 1.0    1-2 Year             No                    1
# 379926                 1.0    < 1 Year             No                    1
# 379927                 1.0    < 1 Year             No                    1
# 379928                 0.0   > 2 Years            Yes                    0
# 379929                 0.0    1-2 Year             No                    1
#
#         vehical damage - Yes  annual premium (in Rs)  sales channel code  \
# 0                          1                 40454.0                26.0
# 1                          0                 33536.0                26.0
# 2                          1                 38294.0                26.0
# 3                          0                 28619.0               152.0
# 4                          0                 27496.0               152.0
# ...                      ...                     ...                 ...
# 379925                     0                 30170.0                26.0
# 379926                     0                 40016.0               152.0
# 379927                     0                 35118.0               160.0
# 379928                     1                 44617.0               124.0
# 379929                     0                 41777.0                26.0
#
#         vintage  response
# 0         217.0       1.0
# 1         183.0       0.0
# 2          27.0       1.0
# 3         203.0       0.0
# 4          39.0       0.0
# ...         ...       ...
# 379925     88.0       0.0
# 379926    131.0       0.0
# 379927    161.0       0.0
# 379928     74.0       0.0
# 379929    237.0       0.0
#
# [379930 rows x 14 columns]

# %%
master_table.set_index('customer_id')
# Out:
#              Gender   age  driving_licence_present  region code  \
# customer_id
# 1.0             NaN  44.0                        1         28.0
# 2.0             NaN  76.0                        1          3.0
# 3.0             NaN  47.0                        1         28.0
# 4.0             NaN  21.0                        1         11.0
# 5.0             NaN  29.0                        1         41.0
# ...             ...   ...                      ...          ...
# 381105.0        NaN  74.0                        1         26.0
# 381106.0        NaN  30.0                        1         37.0
# 381107.0        NaN  21.0                        1         30.0
# 381108.0        NaN  68.0                        1         14.0
# 381109.0        NaN  46.0                        1         29.0
#
#              previously insured vehicle age vehical damage  \
# customer_id
# 1.0                         0.0   > 2 Years            Yes
# 2.0                         0.0    1-2 Year             No
# 3.0                         0.0   > 2 Years            Yes
# 4.0                         1.0    < 1 Year             No
# 5.0                         1.0    < 1 Year             No
# ...                         ...         ...            ...
# 381105.0                    1.0    1-2 Year             No
# 381106.0                    1.0    < 1 Year             No
# 381107.0                    1.0    < 1 Year             No
# 381108.0                    0.0   > 2 Years            Yes
# 381109.0                    0.0    1-2 Year             No
#
#              vehical damage - No  vehical damage - Yes  \
# customer_id
# 1.0                            0                     1
# 2.0                            1                     0
# 3.0                            0                     1
# 4.0                            1                     0
# 5.0                            1                     0
# ...                          ...                   ...
# 381105.0                       1                     0
# 381106.0                       1                     0
# 381107.0                       1                     0
# 381108.0                       0                     1
# 381109.0                       1                     0
#
#              annual premium (in Rs)  sales channel code  vintage  response
# customer_id
# 1.0                         40454.0                26.0    217.0       1.0
# 2.0                         33536.0                26.0    183.0       0.0
# 3.0                         38294.0                26.0     27.0       1.0
# 4.0                         28619.0               152.0    203.0       0.0
# 5.0                         27496.0               152.0     39.0       0.0
# ...                             ...                 ...      ...       ...
# 381105.0                    30170.0                26.0     88.0       0.0
# 381106.0                    40016.0               152.0    131.0       0.0
# 381107.0                    35118.0               160.0    161.0       0.0
# 381108.0                    44617.0               124.0     74.0       0.0
# 381109.0                    41777.0                26.0    237.0       0.0
#
# [379930 rows x 13 columns]

# %% [markdown]
# # Q4. Company needs some important information from the master table to make decisions for future growth.They needs following information:
# i. Gender wise average annual premium
# ii. Age wise average annual premium
# iii. Is your data balanced between the genders?
# (Hint: Data is balanced if number of counts in each group is approximately same)
# iv. Vehicle age wise average annual premium.

# %%
## i: Gender wise average annual premium
plt.figure(figsize = (14, 5))
sns.distplot(master_table.loc[(master_table['Gender'] == 1), 'annual premium (in Rs)'])
sns.distplot(master_table.loc[(master_table['Gender'] == 0), 'annual premium (in Rs)'])
plt.title('Gender wise average annual premium', fontsize = 15)
plt.show()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\2039690365.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['Gender'] == 1), 'annual premium (in Rs)'])
# C:\Users\91708\anaconda3\lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\2039690365.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['Gender'] == 0), 'annual premium (in Rs)'])
# C:\Users\91708\anaconda3\lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
## i: Age wise average annual premium
plt.figure(figsize = (14, 5))
sns.distplot(master_table.loc[(master_table['age'] == 44), 'annual premium (in Rs)'])
sns.distplot(master_table.loc[(master_table['age'] == 21), 'annual premium (in Rs)'])
plt.title('Age wise average annual premium', fontsize = 14)
plt.show()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\3597560698.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['age'] == 44), 'annual premium (in Rs)'])
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\3597560698.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['age'] == 21), 'annual premium (in Rs)'])

# %%
## i: Gender wise average annual premium
plt.figure(figsize = (15, 6))
sns.distplot(master_table.loc[(master_table['driving_licence_present'] == 0), 'age'])
sns.distplot(master_table.loc[(master_table['driving_licence_present'] == 1), 'age'])
plt.title('Age distriution by license', fontsize = 15)
plt.show()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\3001885382.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['driving_licence_present'] == 0), 'age'])
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\3001885382.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['driving_licence_present'] == 1), 'age'])

# %%
master_table
# Out:
#         customer_id  Gender   age  driving_licence_present  region code  \
# 0               1.0     NaN  44.0                        1         28.0
# 1               2.0     NaN  76.0                        1          3.0
# 2               3.0     NaN  47.0                        1         28.0
# 3               4.0     NaN  21.0                        1         11.0
# 4               5.0     NaN  29.0                        1         41.0
# ...             ...     ...   ...                      ...          ...
# 379925     381105.0     NaN  74.0                        1         26.0
# 379926     381106.0     NaN  30.0                        1         37.0
# 379927     381107.0     NaN  21.0                        1         30.0
# 379928     381108.0     NaN  68.0                        1         14.0
# 379929     381109.0     NaN  46.0                        1         29.0
#
#         previously insured vehicle age vehical damage  vehical damage - No  \
# 0                      0.0   > 2 Years            Yes                    0
# 1                      0.0    1-2 Year             No                    1
# 2                      0.0   > 2 Years            Yes                    0
# 3                      1.0    < 1 Year             No                    1
# 4                      1.0    < 1 Year             No                    1
# ...                    ...         ...            ...                  ...
# 379925                 1.0    1-2 Year             No                    1
# 379926                 1.0    < 1 Year             No                    1
# 379927                 1.0    < 1 Year             No                    1
# 379928                 0.0   > 2 Years            Yes                    0
# 379929                 0.0    1-2 Year             No                    1
#
#         vehical damage - Yes  annual premium (in Rs)  sales channel code  \
# 0                          1                 40454.0                26.0
# 1                          0                 33536.0                26.0
# 2                          1                 38294.0                26.0
# 3                          0                 28619.0               152.0
# 4                          0                 27496.0               152.0
# ...                      ...                     ...                 ...
# 379925                     0                 30170.0                26.0
# 379926                     0                 40016.0               152.0
# 379927                     0                 35118.0               160.0
# 379928                     1                 44617.0               124.0
# 379929                     0                 41777.0                26.0
#
#         vintage  response
# 0         217.0       1.0
# 1         183.0       0.0
# 2          27.0       1.0
# 3         203.0       0.0
# 4          39.0       0.0
# ...         ...       ...
# 379925     88.0       0.0
# 379926    131.0       0.0
# 379927    161.0       0.0
# 379928     74.0       0.0
# 379929    237.0       0.0
#
# [379930 rows x 14 columns]

# %%
master_table.groupby('Gender',0).sum()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\30877748.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   master_table.groupby('Gender',0).sum()
# Empty DataFrame
# Columns: [customer_id, age, driving_licence_present, region code, previously insured, vehical damage - No, vehical damage - Yes, annual premium (in Rs), sales channel code, vintage, response]
# Index: []

# %%
## iv: Vehicle age wise average annual premium.
plt.figure(figsize = (12, 4))
sns.distplot(master_table.loc[(master_table['vehicle age'] == 5), 'annual premium (in Rs)'])
sns.distplot(master_table.loc[(master_table['vehicle age'] == 4), 'annual premium (in Rs)'])
plt.title('vehicle age wise average annual premium', fontsize = 14)
plt.show()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\2528718502.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['vehicle age'] == 5), 'annual premium (in Rs)'])
# C:\Users\91708\anaconda3\lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\2528718502.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(master_table.loc[(master_table['vehicle age'] == 4), 'annual premium (in Rs)'])
# C:\Users\91708\anaconda3\lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\91708\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# # 5. Is there any relation between Person Age and annual premium?
# Hint: use correlation function (Correlation describes the relationship between two variables).
# Correlation coefficient < -0.5 - Strong negative relationship
# Correlation coefficient > 0.5 - Strong positive relationship
# 0.5 < Correlation coefficient < 0.5 - There is no relationship.

# %%
corrMatrix = master_table.corr()
sns.heatmap(corrMatrix, annot = True)
plt.show()
# Out:
# C:\Users\91708\AppData\Local\Temp\ipykernel_5292\2667927222.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrMatrix = master_table.corr()
